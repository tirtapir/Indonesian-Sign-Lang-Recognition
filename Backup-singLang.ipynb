# %% [markdown]
# # Import and Install Dependencies

# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Obtaining dependency information for opencv-python from https://files.pythonhosted.org/packages/66/82/564168a349148298aca281e342551404ef5521f33fba17b388ead0a84dc5/opencv_python-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl.metadata
#   Downloading opencv_python-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from opencv-python) (1.24.0)
# Downloading opencv_python-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl (54.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.8/54.8 MB 2.0 MB/s eta 0:00:0000:0100:01
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.10.0.84
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mediapipe
# Out:
# Collecting mediapipe
#   Obtaining dependency information for mediapipe from https://files.pythonhosted.org/packages/31/fb/09fde872bd3c92720860adc25ffee605f18d3a5165320ae8cd2d71da7003/mediapipe-0.10.14-cp311-cp311-macosx_11_0_universal2.whl.metadata
#   Downloading mediapipe-0.10.14-cp311-cp311-macosx_11_0_universal2.whl.metadata (9.7 kB)
# Requirement already satisfied: absl-py in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from mediapipe) (2.1.0)
# Requirement already satisfied: attrs>=19.1.0 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from mediapipe) (22.1.0)
# Collecting flatbuffers>=2.0 (from mediapipe)
#   Obtaining dependency information for flatbuffers>=2.0 from https://files.pythonhosted.org/packages/41/f0/7e988a019bc54b2dbd0ad4182ef2d53488bb02e58694cd79d61369e85900/flatbuffers-24.3.25-py2.py3-none-any.whl.metadata
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting jax (from mediapipe)
#   Obtaining dependency information for jax from https://files.pythonhosted.org/packages/fd/f2/9dbb75de3058acfd1600cf0839bcce7ea391148c9d2b4fa5f5666e66f09e/jax-0.4.30-py3-none-any.whl.metadata
#   Downloading jax-0.4.30-py3-none-any.whl.metadata (22 kB)
# Collecting jaxlib (from mediapipe)
#   Obtaining dependency information for jaxlib from https://files.pythonhosted.org/packages/12/95/399da9204c3b13696baefb93468402f3389416b0caecfd9126aa94742bf2/jaxlib-0.4.30-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading jaxlib-0.4.30-cp311-cp311-macosx_11_0_arm64.whl.metadata (1.0 kB)
# Requirement already satisfied: matplotlib in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from mediapipe) (3.7.2)
# Requirement already satisfied: numpy in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from mediapipe) (1.24.0)
# Collecting opencv-contrib-python (from mediapipe)
#   Obtaining dependency information for opencv-contrib-python from https://files.pythonhosted.org/packages/92/64/c1194510eaed272d86b53a08c790ca6ed1c450f06d401c49c8145fc46d40/opencv_contrib_python-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl.metadata
#   Downloading opencv_contrib_python-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting protobuf<5,>=4.25.3 (from mediapipe)
#   Obtaining dependency information for protobuf<5,>=4.25.3 from https://files.pythonhosted.org/packages/f3/bf/26deba06a4c910a85f78245cac7698f67cedd7efe00d04f6b3e1b3506a59/protobuf-4.25.3-cp37-abi3-macosx_10_9_universal2.whl.metadata
#   Using cached protobuf-4.25.3-cp37-abi3-macosx_10_9_universal2.whl.metadata (541 bytes)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Obtaining dependency information for sounddevice>=0.4.4 from https://files.pythonhosted.org/packages/1c/9c/d8de668a462b7a326d9f697dfa2adb6fbde07cc468cc7cdcf51cbe975d56/sounddevice-0.4.7-py3-none-macosx_10_6_x86_64.macosx_10_6_universal2.whl.metadata
#   Downloading sounddevice-0.4.7-py3-none-macosx_10_6_x86_64.macosx_10_6_universal2.whl.metadata (1.4 kB)
# Requirement already satisfied: CFFI>=1.0 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from sounddevice>=0.4.4->mediapipe) (1.15.1)
# Collecting ml-dtypes>=0.2.0 (from jax->mediapipe)
#   Obtaining dependency information for ml-dtypes>=0.2.0 from https://files.pythonhosted.org/packages/42/6b/b2fa3e2386c2b7dde43f12b83c67f6e583039141dfbb58e5c8fd365a5a7d/ml_dtypes-0.4.0-cp311-cp311-macosx_10_9_universal2.whl.metadata
#   Downloading ml_dtypes-0.4.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (20 kB)
# Collecting opt-einsum (from jax->mediapipe)
#   Obtaining dependency information for opt-einsum from https://files.pythonhosted.org/packages/bc/19/404708a7e54ad2798907210462fd950c3442ea51acc8790f3da48d2bee8b/opt_einsum-3.3.0-py3-none-any.whl.metadata
#   Downloading opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: scipy>=1.9 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from jax->mediapipe) (1.12.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from matplotlib->mediapipe) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from matplotlib->mediapipe) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from matplotlib->mediapipe) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from matplotlib->mediapipe) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from matplotlib->mediapipe) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from matplotlib->mediapipe) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: pycparser in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: six>=1.5 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Downloading mediapipe-0.10.14-cp311-cp311-macosx_11_0_universal2.whl (50.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 MB 2.1 MB/s eta 0:00:0000:0100:01
# Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Using cached protobuf-4.25.3-cp37-abi3-macosx_10_9_universal2.whl (394 kB)
# Downloading sounddevice-0.4.7-py3-none-macosx_10_6_x86_64.macosx_10_6_universal2.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.4/108.4 kB 1.9 MB/s eta 0:00:00 0:00:01
# Downloading jax-0.4.30-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 2.2 MB/s eta 0:00:0000:0100:01
# Downloading jaxlib-0.4.30-cp311-cp311-macosx_11_0_arm64.whl (66.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.7/66.7 MB 2.1 MB/s eta 0:00:0000:0100:01
# Downloading opencv_contrib_python-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl (63.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 MB 2.2 MB/s eta 0:00:0000:0100:01
# Downloading ml_dtypes-0.4.0-cp311-cp311-macosx_10_9_universal2.whl (390 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.9/390.9 kB 2.2 MB/s eta 0:00:00a 0:00:01
# Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Installing collected packages: flatbuffers, protobuf, opt-einsum, opencv-contrib-python, ml-dtypes, sounddevice, jaxlib, jax, mediapipe
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.27.1
#     Uninstalling protobuf-5.27.1:
#       Successfully uninstalled protobuf-5.27.1
# Successfully installed flatbuffers-24.3.25 jax-0.4.30 jaxlib-0.4.30 mediapipe-0.10.14 ml-dtypes-0.4.0 opencv-contrib-python-4.10.0.84 opt-einsum-3.3.0 protobuf-4.25.3 sounddevice-0.4.7
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (1.8.0)
# Requirement already satisfied: absl-py>=0.1.6 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astor>=0.6.0 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from tensorflow) (0.8.1)
# Requirement already satisfied: gast>=0.2.0 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: numpy>=1.13.3 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from tensorflow) (1.24.0)
# Requirement already satisfied: six>=1.10.0 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: protobuf>=3.4.0 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from tensorflow) (4.25.3)
# Requirement already satisfied: tensorboard<1.9.0,>=1.8.0 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from tensorflow) (1.8.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: grpcio>=1.8.6 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: wheel>=0.26 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from tensorflow) (0.43.0)
# Requirement already satisfied: werkzeug>=0.11.10 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from tensorboard<1.9.0,>=1.8.0->tensorflow) (2.2.3)
# Requirement already satisfied: html5lib==0.9999999 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from tensorboard<1.9.0,>=1.8.0->tensorflow) (0.9999999)
# Requirement already satisfied: markdown>=2.6.8 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from tensorboard<1.9.0,>=1.8.0->tensorflow) (3.4.1)
# Requirement already satisfied: bleach==1.5.0 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from tensorboard<1.9.0,>=1.8.0->tensorflow) (1.5.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from werkzeug>=0.11.10->tensorboard<1.9.0,>=1.8.0->tensorflow) (2.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c apple tensorflow-deps
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/noarch::conda-pack==0.6.0=pyhd3eb1b0_0
#   - defaults/noarch::python-slugify==5.0.2=pyhd3eb1b0_0
#   - defaults/osx-arm64::jupyterlab_server==2.22.0=py311hca03da5_0
#   - defaults/osx-arm64::aiohttp==3.8.5=py311h80987f9_0
#   - defaults/osx-arm64::jellyfish==1.0.1=py311h15d1925_0
#   - defaults/noarch::ptyprocess==0.7.0=pyhd3eb1b0_2
#   - defaults/osx-arm64::sympy==1.11.1=py311hca03da5_0
#   - defaults/osx-arm64::python-kaleido==0.2.1=py311hca03da5_0
#   - defaults/osx-arm64::dask-core==2023.6.0=py311hca03da5_0
#   - defaults/osx-arm64::pyodbc==4.0.34=py311h313beb8_0
#   - defaults/osx-arm64::anaconda-anon-usage==0.4.2=py311hd6b623d_0
#   - defaults/osx-arm64::scikit-image==0.20.0=py311h313beb8_0
#   - defaults/noarch::yapf==0.31.0=pyhd3eb1b0_0
#   - defaults/osx-arm64::pathspec==0.10.3=py311hca03da5_0
#   - defaults/osx-arm64::pyerfa==2.0.0=py311h80987f9_0
#   - defaults/osx-arm64::python-lmdb==1.4.1=py311h313beb8_0
#   - defaults/osx-arm64::tenacity==8.2.2=py311hca03da5_0
#   - defaults/noarch::poyo==0.5.0=pyhd3eb1b0_0
#   - defaults/osx-arm64::boltons==23.0.0=py311hca03da5_0
#   - defaults/osx-arm64::packaging==23.1=py311hca03da5_0
#   - defaults/osx-arm64::pywavelets==1.4.1=py311h80987f9_0
#   - defaults/noarch::qdarkstyle==3.0.2=pyhd3eb1b0_0
#   - defaults/noarch::requests-file==1.5.1=pyhd3eb1b0_0
#   - defaults/osx-arm64::black==23.3.0=py311hca03da5_0
#   - defaults/noarch::alabaster==0.7.12=pyhd3eb1b0_0
#   - defaults/osx-arm64::rfc3986-validator==0.1.1=py311hca03da5_0
#   - defaults/osx-arm64::py-lief==0.12.3=py311h313beb8_0
#   - defaults/osx-arm64::jupyter_ydoc==0.2.4=py311hca03da5_0
#   - defaults/osx-arm64::bokeh==3.2.1=py311hb6e6a13_0
#   - defaults/osx-arm64::argon2-cffi-bindings==21.2.0=py311h80987f9_0
#   - defaults/osx-arm64::_anaconda_depends==2023.09=py311_openblas_1
#   - defaults/osx-arm64::pep8==1.7.1=py311hca03da5_1
#   - defaults/osx-arm64::anaconda-project==0.11.1=py311hca03da5_0
#   - defaults/noarch::charset-normalizer==2.0.4=pyhd3eb1b0_0
#   - defaults/osx-arm64::pygments==2.15.1=py311hca03da5_1
#   - defaults/noarch::sortedcontainers==2.4.0=pyhd3eb1b0_0
#   - defaults/osx-arm64::fsspec==2023.4.0=py311hca03da5_0
#   - defaults/osx-arm64::pyparsing==3.0.9=py311hca03da5_0
#   - defaults/osx-arm64::docstring-to-markdown==0.11=py311hca03da5_0
#   - defaults/osx-arm64::python-lsp-black==1.2.1=py311hca03da5_0
#   - defaults/osx-arm64::lazy-object-proxy==1.6.0=py311h80987f9_0
#   - defaults/osx-arm64::pyarrow==11.0.0=py311h7575258_1
#   - defaults/osx-arm64::dill==0.3.6=py311hca03da5_0
#   - defaults/osx-arm64::tinycss2==1.2.1=py311hca03da5_0
#   - defaults/noarch::asttokens==2.0.5=pyhd3eb1b0_0
#   - defaults/osx-arm64::pyqt==5.15.7=py311h313beb8_0
#   - defaults/noarch::cookiecutter==1.7.3=pyhd3eb1b0_0
#   - defaults/osx-arm64::watchdog==2.1.6=py311h80987f9_0
#   - defaults/osx-arm64::pyobjc-core==9.0=py311h3eb5a62_1
#   - defaults/noarch::munkres==1.1.4=py_0
#   - defaults/noarch::itemloaders==1.0.4=pyhd3eb1b0_1
#   - defaults/osx-arm64::pillow==9.4.0=py311h313beb8_1
#   - defaults/noarch::isort==5.9.3=pyhd3eb1b0_0
#   - defaults/noarch::itsdangerous==2.0.1=pyhd3eb1b0_0
#   - defaults/osx-arm64::jupyter_console==6.6.3=py311hca03da5_0
#   - defaults/noarch::pyasn1==0.4.8=pyhd3eb1b0_0
#   - defaults/noarch::argon2-cffi==21.3.0=pyhd3eb1b0_0
#   - defaults/osx-arm64::patsy==0.5.3=py311hca03da5_0
#   - defaults/noarch::slicer==0.0.7=pyhd3eb1b0_0
#   - defaults/osx-arm64::pyflakes==3.0.1=py311hca03da5_0
#   - defaults/noarch::jsonpatch==1.32=pyhd3eb1b0_0
#   - defaults/osx-arm64::anaconda-catalogs==0.2.0=py311hca03da5_0
#   - defaults/osx-arm64::pyzmq==23.2.0=py311h313beb8_0
#   - defaults/noarch::defusedxml==0.7.1=pyhd3eb1b0_0
#   - defaults/osx-arm64::keyring==23.13.1=py311hca03da5_0
#   - defaults/osx-arm64::tabulate==0.8.10=py311hca03da5_0
#   - defaults/osx-arm64::yarl==1.8.1=py311h80987f9_0
#   - defaults/osx-arm64::notebook==6.5.4=py311hca03da5_1
#   - defaults/osx-arm64::cloudpickle==2.2.1=py311hca03da5_0
#   - defaults/osx-arm64::gdal==3.6.2=py311h950983f_3
#   - defaults/osx-arm64::importlib-metadata==6.0.0=py311hca03da5_0
#   - defaults/osx-arm64::pip==23.2.1=py311hca03da5_0
#   - defaults/osx-arm64::jupyter_core==5.3.0=py311hca03da5_0
#   - defaults/noarch::atomicwrites==1.4.0=py_0
#   - defaults/noarch::aiosignal==1.2.0=pyhd3eb1b0_0
#   - defaults/osx-arm64::widgetsnbextension==4.0.5=py311hca03da5_0
#   - defaults/noarch::py-cpuinfo==8.0.0=pyhd3eb1b0_1
#   - defaults/osx-arm64::partd==1.4.0=py311hca03da5_0
#   - defaults/osx-arm64::rfc3339-validator==0.1.4=py311hca03da5_0
#   - defaults/osx-arm64::pydispatcher==2.0.5=py311hca03da5_2
#   - defaults/osx-arm64::plotly==5.9.0=py311hca03da5_0
#   - defaults/osx-arm64::conda-package-streaming==0.9.0=py311hca03da5_0
#   - defaults/osx-arm64::cytoolz==0.12.0=py311h80987f9_0
#   - defaults/noarch::sphinxcontrib-htmlhelp==2.0.0=pyhd3eb1b0_0
#   - defaults/osx-arm64::websocket-client==0.58.0=py311hca03da5_4
#   - defaults/osx-arm64::python-json-logger==2.0.7=py311hca03da5_0
#   - defaults/noarch::backports.functools_lru_cache==1.6.4=pyhd3eb1b0_0
#   - defaults/osx-arm64::twisted==22.10.0=py311h80987f9_0
#   - defaults/osx-arm64::jsonschema==4.17.3=py311hca03da5_0
#   - defaults/osx-arm64::lxml==4.9.3=py311h50ffb84_0
#   - defaults/osx-arm64::colorama==0.4.6=py311hca03da5_0
#   - defaults/osx-arm64::datashape==0.5.4=py311hca03da5_1
#   - defaults/osx-arm64::numexpr==2.8.4=py311h6dc990b_1
#   - defaults/osx-arm64::entrypoints==0.4=py311hca03da5_0
#   - defaults/osx-arm64::nbconvert==6.5.4=py311hca03da5_0
#   - defaults/osx-arm64::pylint==2.16.2=py311hca03da5_0
#   - defaults/noarch::pycparser==2.21=pyhd3eb1b0_0
#   - defaults/noarch::parso==0.8.3=pyhd3eb1b0_0
#   - defaults/osx-arm64::aiofiles==22.1.0=py311hca03da5_0
#   - defaults/osx-arm64::jupyter_server_ydoc==0.8.0=py311hca03da5_1
#   - defaults/noarch::binaryornot==0.4.4=pyhd3eb1b0_1
#   - defaults/osx-arm64::comm==0.1.2=py311hca03da5_0
#   - defaults/osx-arm64::xyzservices==2022.9.0=py311hca03da5_1
#   - defaults/osx-arm64::mistune==0.8.4=py311h80987f9_1000
#   - defaults/osx-arm64::markdown-it-py==2.2.0=py311hca03da5_1
#   - defaults/osx-arm64::idna==3.4=py311hca03da5_0
#   - defaults/osx-arm64::qtawesome==1.2.2=py311hca03da5_0
#   - defaults/noarch::pyls-spyder==0.4.0=pyhd3eb1b0_0
#   - defaults/osx-arm64::dask==2023.6.0=py311hca03da5_0
#   - defaults/osx-arm64::cffi==1.15.1=py311h80987f9_3
#   - defaults/osx-arm64::docutils==0.18.1=py311hca03da5_3
#   - defaults/osx-arm64::jupyterlab==3.6.3=py311hca03da5_0
#   - defaults/osx-arm64::s3fs==2023.4.0=py311hca03da5_0
#   - defaults/osx-arm64::mdurl==0.1.0=py311hca03da5_0
#   - defaults/osx-arm64::constantly==15.1.0=py311hca03da5_0
#   - defaults/osx-arm64::linkify-it-py==2.0.0=py311hca03da5_0
#   - defaults/noarch::json5==0.9.6=pyhd3eb1b0_0
#   - defaults/noarch::six==1.16.0=pyhd3eb1b0_1
#   - defaults/osx-arm64::pyopenssl==23.2.0=py311hca03da5_0
#   - defaults/osx-arm64::datasets==2.12.0=py311hca03da5_0
#   - defaults/osx-arm64::pyrsistent==0.18.0=py311h80987f9_0
#   - defaults/osx-arm64::pycodestyle==2.10.0=py311hca03da5_0
#   - defaults/noarch::jmespath==0.10.0=pyhd3eb1b0_0
#   - defaults/osx-arm64::conda-index==0.3.0=py311hca03da5_0
#   - defaults/osx-arm64::ypy-websocket==0.8.2=py311hca03da5_0
#   - defaults/noarch::backports.tempfile==1.0=pyhd3eb1b0_1
#   - defaults/osx-arm64::mdit-py-plugins==0.3.0=py311hca03da5_0
#   - defaults/osx-arm64::numpy==1.24.3=py311hb57d4eb_0
#   - defaults/noarch::decorator==5.1.1=pyhd3eb1b0_0
#   - defaults/noarch::executing==0.8.3=pyhd3eb1b0_0
#   - defaults/osx-arm64::zict==2.2.0=py311hca03da5_0
#   - defaults/osx-arm64::spyder==5.4.3=py311hca03da5_1
#   - defaults/osx-arm64::toolz==0.12.0=py311hca03da5_0
#   - defaults/noarch::sphinxcontrib-jsmath==1.0.1=pyhd3eb1b0_0
#   - defaults/osx-arm64::huggingface_hub==0.15.1=py311hca03da5_0
#   - defaults/osx-arm64::pylint-venv==2.3.0=py311hca03da5_0
#   - defaults/osx-arm64::qtpy==2.2.0=py311hca03da5_0
#   - defaults/osx-arm64::whatthepatch==1.0.2=py311hca03da5_0
#   - defaults/osx-arm64::zope.interface==5.4.0=py311h80987f9_0
#   - defaults/osx-arm64::openpyxl==3.0.10=py311h80987f9_0
#   - defaults/osx-arm64::anaconda-navigator==2.5.0=py311hca03da5_0
#   - defaults/osx-arm64::pkginfo==1.9.6=py311hca03da5_0
#   - defaults/osx-arm64::beautifulsoup4==4.12.2=py311hca03da5_0
#   - defaults/noarch::snowballstemmer==2.2.0=pyhd3eb1b0_0
#   - defaults/noarch::pexpect==4.8.0=pyhd3eb1b0_3
#   - defaults/osx-arm64::sniffio==1.2.0=py311hca03da5_1
#   - defaults/noarch::fonttools==4.25.0=pyhd3eb1b0_0
#   - defaults/osx-arm64::pysocks==1.7.1=py311hca03da5_0
#   - defaults/osx-arm64::mpmath==1.3.0=py311hca03da5_0
#   - defaults/osx-arm64::h5py==3.9.0=py311hba6ad2f_0
#   - defaults/osx-arm64::future==0.18.3=py311hca03da5_0
#   - defaults/osx-arm64::uc-micro-py==1.0.1=py311hca03da5_0
#   - defaults/osx-arm64::pyjwt==2.4.0=py311hca03da5_0
#   - defaults/osx-arm64::multiprocess==0.70.14=py311hca03da5_0
#   - defaults/osx-arm64::rtree==1.0.1=py311hca03da5_0
#   - defaults/osx-arm64::pkce==1.0.3=py311hca03da5_0
#   - defaults/osx-arm64::notebook-shim==0.2.2=py311hca03da5_0
#   - defaults/osx-arm64::flask==2.2.2=py311hca03da5_0
#   - defaults/osx-arm64::contourpy==1.0.5=py311h48ca7d4_0
#   - defaults/osx-arm64::requests-toolbelt==1.0.0=py311hca03da5_0
#   - defaults/osx-arm64::jupyter_events==0.6.3=py311hca03da5_0
#   - defaults/noarch::incremental==21.3.0=pyhd3eb1b0_0
#   - defaults/osx-arm64::transformers==4.32.1=py311hca03da5_0
#   - defaults/osx-arm64::webencodings==0.5.1=py311hca03da5_1
#   - defaults/osx-arm64::brotlipy==0.7.0=py311h80987f9_1002
#   - defaults/osx-arm64::safetensors==0.3.2=py311hf0e4da2_0
#   - defaults/noarch::text-unidecode==1.3=pyhd3eb1b0_0
#   - defaults/osx-arm64::zope==1.0=py311hca03da5_1
#   - conda-forge/noarch::certifi==2024.6.2=pyhd8ed1ab_0
#   - defaults/osx-arm64::jupyter_server==1.23.4=py311hca03da5_0
#   - defaults/osx-arm64::psutil==5.9.0=py311h80987f9_0
#   - defaults/osx-arm64::appnope==0.1.2=py311hca03da5_1001
#   - defaults/osx-arm64::locket==1.0.0=py311hca03da5_0
#   - defaults/osx-arm64::greenlet==2.0.1=py311h313beb8_0
#   - defaults/osx-arm64::xarray==2023.6.0=py311hca03da5_0
#   - defaults/noarch::tblib==1.7.0=pyhd3eb1b0_0
#   - defaults/osx-arm64::nbclassic==0.5.5=py311hca03da5_0
#   - defaults/osx-arm64::jupyter_server_fileid==0.9.0=py311hca03da5_0
#   - defaults/osx-arm64::tornado==6.3.2=py311h80987f9_0
#   - defaults/osx-arm64::multidict==6.0.2=py311h80987f9_0
#   - defaults/osx-arm64::hvplot==0.8.4=py311hca03da5_0
#   - defaults/osx-arm64::conda-content-trust==0.2.0=py311hca03da5_0
#   - defaults/noarch::importlib_metadata==6.0.0=hd3eb1b0_0
#   - defaults/osx-arm64::nltk==3.8.1=py311hca03da5_0
#   - defaults/noarch::diff-match-patch==20200713=pyhd3eb1b0_0
#   - defaults/osx-arm64::wurlitzer==3.0.2=py311hca03da5_0
#   - defaults/osx-arm64::conda-build==3.26.1=py311hca03da5_0
#   - defaults/osx-arm64::pytest==7.4.0=py311hca03da5_0
#   - defaults/osx-arm64::qstylizer==0.2.2=py311hca03da5_0
#   - defaults/noarch::more-itertools==8.12.0=pyhd3eb1b0_0
#   - defaults/osx-arm64::qtconsole==5.4.2=py311hca03da5_0
#   - defaults/osx-arm64::ipython==8.15.0=py311hca03da5_0
#   - defaults/noarch::sphinxcontrib-applehelp==1.0.2=pyhd3eb1b0_0
#   - defaults/osx-arm64::python-lsp-server==1.7.2=py311hca03da5_0
#   - defaults/osx-arm64::aiobotocore==2.5.0=py311hca03da5_0
#   - defaults/osx-arm64::statsmodels==0.14.0=py311hb9f6ed7_0
#   - defaults/osx-arm64::werkzeug==2.2.3=py311hca03da5_0
#   - defaults/noarch::wcwidth==0.2.5=pyhd3eb1b0_0
#   - defaults/osx-arm64::nbclient==0.5.13=py311hca03da5_0
#   - defaults/noarch::unidecode==1.2.0=pyhd3eb1b0_0
#   - defaults/osx-arm64::pyqtwebengine==5.15.7=py311h313beb8_0
#   - defaults/osx-arm64::aiosqlite==0.18.0=py311hca03da5_0
#   - defaults/osx-arm64::zstandard==0.19.0=py311h80987f9_0
#   - defaults/osx-arm64::pluggy==1.0.0=py311hca03da5_1
#   - defaults/noarch::conda-verify==3.4.2=py_1
#   - defaults/osx-arm64::matplotlib-inline==0.1.6=py311hca03da5_0
#   - defaults/osx-arm64::platformdirs==3.10.0=py311hca03da5_0
#   - defaults/noarch::itemadapter==0.3.0=pyhd3eb1b0_0
#   - defaults/noarch::pyasn1-modules==0.2.8=py_0
#   - defaults/osx-arm64::msgpack-python==1.0.3=py311h48ca7d4_0
#   - defaults/noarch::autopep8==1.6.0=pyhd3eb1b0_1
#   - defaults/noarch::send2trash==1.8.0=pyhd3eb1b0_1
#   - defaults/noarch::responses==0.13.3=pyhd3eb1b0_0
#   - defaults/osx-arm64::anaconda-cloud-auth==0.1.3=py311hca03da5_0
#   - defaults/osx-arm64::pyyaml==6.0=py311h80987f9_1
#   - defaults/osx-arm64::datashader==0.15.2=py311hca03da5_0
#   - defaults/noarch::protego==0.1.16=py_0
#   - defaults/osx-arm64::anaconda-client==1.12.1=py311hca03da5_0
#   - defaults/osx-arm64::attrs==22.1.0=py311hca03da5_0
#   - defaults/noarch::iniconfig==1.1.1=pyhd3eb1b0_0
#   - defaults/osx-arm64::typing-extensions==4.7.1=py311hca03da5_0
#   - defaults/noarch::cycler==0.11.0=pyhd3eb1b0_0
#   - defaults/osx-arm64::gmpy2==2.1.2=py311h40f64dc_0
#   - defaults/osx-arm64::pyqt5-sip==12.11.0=py311h313beb8_0
#   - defaults/noarch::prompt_toolkit==3.0.36=hd3eb1b0_0
#   - defaults/osx-arm64::conda-package-handling==2.2.0=py311hca03da5_0
#   - defaults/noarch::jupyterlab_pygments==0.1.2=py_0
#   - defaults/noarch::jinja2-time==0.2.0=pyhd3eb1b0_3
#   - defaults/noarch::textdistance==4.2.1=pyhd3eb1b0_0
#   - defaults/noarch::ipython_genutils==0.2.0=pyhd3eb1b0_1
#   - defaults/osx-arm64::pyobjc-framework-cocoa==9.0=py311hb094c41_0
#   - defaults/osx-arm64::smart_open==5.2.1=py311hca03da5_0
#   - defaults/osx-arm64::jinja2==3.1.2=py311hca03da5_0
#   - defaults/osx-arm64::conda-libmamba-solver==23.7.0=py311hca03da5_0
#   - defaults/noarch::toml==0.10.2=pyhd3eb1b0_0
#   - defaults/osx-arm64::shap==0.42.1=py311h7aedaa7_0
#   - defaults/noarch::w3lib==1.21.0=pyhd3eb1b0_0
#   - defaults/osx-arm64::tifffile==2023.4.12=py311hca03da5_0
#   - defaults/osx-arm64::kiwisolver==1.4.4=py311h313beb8_0
#   - defaults/noarch::jaraco.classes==3.2.1=pyhd3eb1b0_0
#   - defaults/osx-arm64::appscript==1.1.2=py311h80987f9_0
#   - defaults/osx-arm64::prompt-toolkit==3.0.36=py311hca03da5_0
#   - defaults/osx-arm64::astropy==5.1=py311ha0d4635_0
#   - defaults/noarch::pathlib==1.0.1=pyhd3eb1b0_1
#   - defaults/noarch::cssselect==1.1.0=pyhd3eb1b0_0
#   - defaults/osx-arm64::pydantic==1.10.8=py311h80987f9_0
#   - defaults/osx-arm64::imageio==2.31.1=py311hca03da5_0
#   - defaults/osx-arm64::chardet==4.0.0=py311hca03da5_1003
#   - defaults/noarch::sphinxcontrib-qthelp==1.0.3=pyhd3eb1b0_0
#   - defaults/osx-arm64::pytables==3.8.0=py311he080bb3_3
#   - defaults/noarch::three-merge==0.1.1=pyhd3eb1b0_0
#   - defaults/osx-arm64::botocore==1.29.76=py311hca03da5_0
#   - defaults/noarch::python-lsp-jsonrpc==1.0.0=pyhd3eb1b0_0
#   - defaults/noarch::backcall==0.2.0=pyhd3eb1b0_0
#   - defaults/osx-arm64::imagecodecs==2023.1.23=py311h5e7c512_0
#   - defaults/osx-arm64::sphinx==5.0.2=py311hca03da5_0
#   - defaults/noarch::glob2==0.7=pyhd3eb1b0_0
#   - defaults/osx-arm64::pycurl==7.45.2=py311h02f6b3c_1
#   - defaults/osx-arm64::terminado==0.17.1=py311hca03da5_0
#   - defaults/osx-arm64::scrapy==2.8.0=py311hca03da5_0
#   - defaults/noarch::hyperlink==21.0.0=pyhd3eb1b0_0
#   - defaults/osx-arm64::python-snappy==0.6.1=py311h313beb8_0
#   - defaults/osx-arm64::parsel==1.6.0=py311hca03da5_0
#   - defaults/osx-arm64::nest-asyncio==1.5.6=py311hca03da5_0
#   - defaults/osx-arm64::shapely==2.0.1=py311h3713c0e_0
#   - defaults/osx-arm64::panel==1.2.3=py311hca03da5_0
#   - defaults/osx-arm64::python==3.11.5=hb885b13_0
#   - defaults/noarch::pure_eval==0.2.2=pyhd3eb1b0_0
#   - defaults/osx-arm64::pytoolconfig==1.2.5=py311hca03da5_1
#   - defaults/noarch::heapdict==1.0.1=pyhd3eb1b0_0
#   - defaults/osx-arm64::python-dotenv==0.21.0=py311hca03da5_0
#   - defaults/noarch::appdirs==1.4.4=pyhd3eb1b0_0
#   - defaults/osx-arm64::nbformat==5.9.2=py311hca03da5_0
#   - defaults/osx-arm64::bottleneck==1.3.5=py311ha0d4635_0
#   - defaults/osx-arm64::astroid==2.14.2=py311hca03da5_0
#   - defaults/osx-arm64::python-fastjsonschema==2.16.2=py311hca03da5_0
#   - defaults/osx-arm64::inflection==0.5.1=py311hca03da5_0
#   - defaults/noarch::sphinxcontrib-serializinghtml==1.1.5=pyhd3eb1b0_0
#   - defaults/osx-arm64::numpydoc==1.5.0=py311hca03da5_0
#   - defaults/osx-arm64::markdown==3.4.1=py311hca03da5_0
#   - defaults/osx-arm64::conda-repo-cli==1.0.75=py311hca03da5_0
#   - defaults/osx-arm64::spyder-kernels==2.4.4=py311hca03da5_0
#   - defaults/osx-arm64::tokenizers==0.13.2=py311h3dd52b7_1
#   - defaults/osx-arm64::holoviews==1.17.1=py311hca03da5_0
#   - defaults/osx-arm64::pyviz_comms==2.3.0=py311hca03da5_0
#   - defaults/osx-arm64::gensim==4.3.0=py311h6956b77_0
#   - defaults/osx-arm64::ipywidgets==8.0.4=py311hca03da5_0
#   - defaults/osx-arm64::python.app==3=py311h80987f9_0
#   - defaults/osx-arm64::flake8==6.0.0=py311hca03da5_0
#   - defaults/osx-arm64::prometheus_client==0.14.1=py311hca03da5_0
#   - defaults/osx-arm64::pydocstyle==6.3.0=py311hca03da5_0
#   - defaults/osx-arm64::jupyterlab_widgets==3.0.5=py311hca03da5_0
#   - defaults/osx-arm64::rope==1.7.0=py311hca03da5_0
#   - defaults/osx-arm64::traitlets==5.7.1=py311hca03da5_0
#   - defaults/noarch::intervaltree==3.1.0=pyhd3eb1b0_0
#   - defaults/noarch::backports==1.1=pyhd3eb1b0_0
#   - defaults/osx-arm64::lz4==4.3.2=py311h80987f9_0
#   - defaults/osx-arm64::babel==2.11.0=py311hca03da5_0
#   - defaults/osx-arm64::ujson==5.4.0=py311h313beb8_0
#   - defaults/osx-arm64::xlwings==0.29.1=py311hca03da5_0
#   - defaults/noarch::aioitertools==0.7.1=pyhd3eb1b0_0
#   - defaults/osx-arm64::clyent==1.2.2=py311hca03da5_1
#   - defaults/noarch::python-libarchive-c==2.9=pyhd3eb1b0_1
#   - defaults/osx-arm64::pycosat==0.6.4=py311h80987f9_0
#   - defaults/osx-arm64::mypy_extensions==1.0.0=py311hca03da5_0
#   - defaults/osx-arm64::ipykernel==6.25.0=py311hb6e6a13_0
#   - defaults/osx-arm64::urllib3==1.26.16=py311hca03da5_0
#   - defaults/osx-arm64::pyobjc-framework-fsevents==9.0=py311hca03da5_0
#   - defaults/osx-arm64::matplotlib-base==3.7.2=py311h7aedaa7_0
#   - defaults/osx-arm64::pyobjc-framework-coreservices==9.0=py311hdd8dd1f_0
#   - defaults/osx-arm64::conda==23.7.4=py311hca03da5_0
#   - defaults/osx-arm64::wrapt==1.14.1=py311h80987f9_0
#   - defaults/osx-arm64::markupsafe==2.1.1=py311h80987f9_0
#   - defaults/osx-arm64::seaborn==0.12.2=py311hca03da5_0
#   - defaults/osx-arm64::y-py==0.5.9=py311ha6e5c4f_0
#   - defaults/osx-arm64::bcrypt==3.2.0=py311h80987f9_1
#   - defaults/osx-arm64::arrow==1.2.3=py311hca03da5_1
#   - defaults/osx-arm64::ruamel_yaml==0.17.21=py311h80987f9_0
#   - defaults/osx-arm64::sip==6.6.2=py311h313beb8_0
#   - defaults/osx-arm64::navigator-updater==0.4.0=py311hca03da5_1
#   - defaults/osx-arm64::et_xmlfile==1.1.0=py311hca03da5_0
#   - defaults/osx-arm64::python-xxhash==2.0.2=py311h80987f9_1
#   - defaults/noarch::jsonpointer==2.1=pyhd3eb1b0_0
#   - defaults/noarch::automat==20.2.0=py_0
#   - defaults/osx-arm64::ply==3.11=py311hca03da5_0
#   - defaults/osx-arm64::soupsieve==2.4=py311hca03da5_0
#   - defaults/noarch::mccabe==0.7.0=pyhd3eb1b0_0
#   - defaults/osx-arm64::tomlkit==0.11.1=py311hca03da5_0
#   - defaults/noarch::conda-token==0.4.0=pyhd3eb1b0_0
#   - defaults/osx-arm64::zipp==3.11.0=py311hca03da5_0
#   - defaults/osx-arm64::async-timeout==4.0.2=py311hca03da5_0
#   - defaults/noarch::service_identity==18.1.0=pyhd3eb1b0_1
#   - defaults/noarch::pickleshare==0.7.5=pyhd3eb1b0_1003
#   - defaults/osx-arm64::libmambapy==1.5.1=py311h1c5506f_0
#   - defaults/osx-arm64::multipledispatch==0.6.0=py311hca03da5_0
#   - defaults/noarch::sphinxcontrib-devhelp==1.0.2=pyhd3eb1b0_0
#   - defaults/osx-arm64::sqlalchemy==1.4.39=py311h80987f9_0
#   - defaults/noarch::stack_data==0.2.0=pyhd3eb1b0_0
#   - defaults/osx-arm64::jedi==0.18.1=py311hca03da5_1
#   - defaults/osx-arm64::debugpy==1.6.7=py311h313beb8_0
#   - defaults/osx-arm64::intake==0.6.8=py311hca03da5_0
#   - defaults/osx-arm64::frozenlist==1.3.3=py311h80987f9_0
#   - defaults/osx-arm64::imagesize==1.4.1=py311hca03da5_0
#   - defaults/osx-arm64::colorcet==3.0.1=py311hca03da5_0
#   - defaults/osx-arm64::networkx==3.1=py311hca03da5_0
#   - defaults/osx-arm64::queuelib==1.5.0=py311hca03da5_0
#   - defaults/osx-arm64::distributed==2023.6.0=py311hca03da5_0
#   - defaults/osx-arm64::jupyter==1.0.0=py311hca03da5_8
#   - defaults/osx-arm64::requests==2.31.0=py311hca03da5_0
#   - defaults/noarch::backports.weakref==1.0.post1=py_1
#   - defaults/osx-arm64::lazy_loader==0.2=py311hca03da5_0
#   - defaults/osx-arm64::anyio==3.5.0=py311hca03da5_0
#   - defaults/osx-arm64::ruamel.yaml==0.17.21=py311h80987f9_0
#   - defaults/noarch::pandocfilters==1.5.0=pyhd3eb1b0_0
#   - defaults/noarch::tldextract==3.2.0=pyhd3eb1b0_0
#   - defaults/osx-arm64::jupyter_client==7.4.9=py311hca03da5_0
#   - defaults/osx-arm64::matplotlib==3.7.2=py311hca03da5_0
#   - defaults/osx-arm64::pyct==0.5.0=py311hca03da5_0
#   - defaults/osx-arm64::param==1.13.0=py311hca03da5_0
#   - defaults/osx-arm64::cryptography==41.0.3=py311hd4332d6_0
#   - defaults/osx-arm64::applaunchservices==0.3.0=py311hca03da5_0
# unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
# Solving environment: unsuccessful attempt using repodata from current_repodata.json, retrying with next repodata source.
# Collecting package metadata (repodata.json): - WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.8.0.*, but conda is ignoring the .* and treating it as 1.8.0
# WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.9.0.*, but conda is ignoring the .* and treating it as 1.9.0
# done
# Solving environment: unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
# Solving environment: \
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
#                                                                                failed
#
# UnsatisfiableError: The following specifications were found to be incompatible with each other:
#
# Output in format: Requested package -> Available versionsThe following specifications were found to be incompatible with your system:
#
#   - feature:/osx-arm64::__osx==14.5=0
#   - feature:|@/osx-arm64::__osx==14.5=0
#   - tensorflow-deps -> grpcio[version='>=1.37.0,<2.0'] -> __osx[version='>=10.9|>=11.0']
#
# Your installed version is: 14.5
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# pip install tensorflow-macos
# Out:
# Collecting tensorflow-macos
#   Obtaining dependency information for tensorflow-macos from https://files.pythonhosted.org/packages/f5/95/ea9b5896e747d35a56642fb3397a21d44315a4d060c8899a09e10f61fe2d/tensorflow_macos-2.16.1-cp311-cp311-macosx_12_0_arm64.whl.metadata
#   Downloading tensorflow_macos-2.16.1-cp311-cp311-macosx_12_0_arm64.whl.metadata (3.5 kB)
# Collecting tensorflow==2.16.1 (from tensorflow-macos)
#   Obtaining dependency information for tensorflow==2.16.1 from https://files.pythonhosted.org/packages/f9/14/67e9b2b2379cb530c0412123a674d045eca387dfcfa7db1c0028857b0a66/tensorflow-2.16.1-cp311-cp311-macosx_12_0_arm64.whl.metadata
#   Downloading tensorflow-2.16.1-cp311-cp311-macosx_12_0_arm64.whl.metadata (4.1 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from tensorflow==2.16.1->tensorflow-macos) (2.1.0)
# Collecting astunparse>=1.6.0 (from tensorflow==2.16.1->tensorflow-macos)
#   Obtaining dependency information for astunparse>=1.6.0 from https://files.pythonhosted.org/packages/2b/03/13dde6512ad7b4557eb792fbcf0c653af6076b81e5941d36ec61f7ce6028/astunparse-1.6.3-py2.py3-none-any.whl.metadata
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from tensorflow==2.16.1->tensorflow-macos) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from tensorflow==2.16.1->tensorflow-macos) (0.5.4)
# Collecting google-pasta>=0.1.1 (from tensorflow==2.16.1->tensorflow-macos)
#   Obtaining dependency information for google-pasta>=0.1.1 from https://files.pythonhosted.org/packages/a3/de/c648ef6835192e6e2cc03f40b19eeda4382c49b5bafb43d88b931c4c74ac/google_pasta-0.2.0-py3-none-any.whl.metadata
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting h5py>=3.10.0 (from tensorflow==2.16.1->tensorflow-macos)
#   Obtaining dependency information for h5py>=3.10.0 from https://files.pythonhosted.org/packages/f0/af/dfbea0c69fe725e9e77259d42f4e14eb582eb094200aaf697feb36f513d8/h5py-3.11.0-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading h5py-3.11.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.5 kB)
# Collecting libclang>=13.0.0 (from tensorflow==2.16.1->tensorflow-macos)
#   Obtaining dependency information for libclang>=13.0.0 from https://files.pythonhosted.org/packages/db/ed/1df62b44db2583375f6a8a5e2ca5432bbdc3edb477942b9b7c848c720055/libclang-18.1.1-py2.py3-none-macosx_11_0_arm64.whl.metadata
#   Downloading libclang-18.1.1-py2.py3-none-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting ml-dtypes~=0.3.1 (from tensorflow==2.16.1->tensorflow-macos)
#   Obtaining dependency information for ml-dtypes~=0.3.1 from https://files.pythonhosted.org/packages/6e/a4/6aabb78f1569550fd77c74d2c1d008b502c8ce72776bd88b14ea6c182c9e/ml_dtypes-0.3.2-cp311-cp311-macosx_10_9_universal2.whl.metadata
#   Downloading ml_dtypes-0.3.2-cp311-cp311-macosx_10_9_universal2.whl.metadata (20 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from tensorflow==2.16.1->tensorflow-macos) (3.3.0)
# Requirement already satisfied: packaging in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from tensorflow==2.16.1->tensorflow-macos) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from tensorflow==2.16.1->tensorflow-macos) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from tensorflow==2.16.1->tensorflow-macos) (2.31.0)
# Requirement already satisfied: setuptools in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from tensorflow==2.16.1->tensorflow-macos) (70.1.0)
# Requirement already satisfied: six>=1.12.0 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from tensorflow==2.16.1->tensorflow-macos) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from tensorflow==2.16.1->tensorflow-macos) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from tensorflow==2.16.1->tensorflow-macos) (4.10.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from tensorflow==2.16.1->tensorflow-macos) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from tensorflow==2.16.1->tensorflow-macos) (1.64.1)
# Collecting tensorboard<2.17,>=2.16 (from tensorflow==2.16.1->tensorflow-macos)
#   Obtaining dependency information for tensorboard<2.17,>=2.16 from https://files.pythonhosted.org/packages/3a/d0/b97889ffa769e2d1fdebb632084d5e8b53fc299d43a537acee7ec0c021a3/tensorboard-2.16.2-py3-none-any.whl.metadata
#   Downloading tensorboard-2.16.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting keras>=3.0.0 (from tensorflow==2.16.1->tensorflow-macos)
#   Obtaining dependency information for keras>=3.0.0 from https://files.pythonhosted.org/packages/8d/44/c604ecc5c9993b6574a681f2f505e980725871a89cfd9e48597b12ccb506/keras-3.3.3-py3-none-any.whl.metadata
#   Downloading keras-3.3.3-py3-none-any.whl.metadata (5.7 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow==2.16.1->tensorflow-macos)
#   Obtaining dependency information for tensorflow-io-gcs-filesystem>=0.23.1 from https://files.pythonhosted.org/packages/72/df/c39b261bd93bde1eb3d6ee5c83d318803255bbe7e642ae345ca6f6a55932/tensorflow_io_gcs_filesystem-0.37.0-cp311-cp311-macosx_12_0_arm64.whl.metadata
#   Downloading tensorflow_io_gcs_filesystem-0.37.0-cp311-cp311-macosx_12_0_arm64.whl.metadata (14 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from tensorflow==2.16.1->tensorflow-macos) (1.24.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow==2.16.1->tensorflow-macos) (0.43.0)
# Collecting rich (from keras>=3.0.0->tensorflow==2.16.1->tensorflow-macos)
#   Obtaining dependency information for rich from https://files.pythonhosted.org/packages/87/67/a37f6214d0e9fe57f6ae54b2956d550ca8365857f42a1ce0392bb21d9410/rich-13.7.1-py3-none-any.whl.metadata
#   Using cached rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.0.0->tensorflow==2.16.1->tensorflow-macos)
#   Obtaining dependency information for namex from https://files.pythonhosted.org/packages/73/59/7854fbfb59f8ae35483ce93493708be5942ebb6328cd85b3a609df629736/namex-0.0.8-py3-none-any.whl.metadata
#   Downloading namex-0.0.8-py3-none-any.whl.metadata (246 bytes)
# Collecting optree (from keras>=3.0.0->tensorflow==2.16.1->tensorflow-macos)
#   Obtaining dependency information for optree from https://files.pythonhosted.org/packages/cc/b8/33127d52de868d2aabc14ec6f53cb2dffafd14c5c708f50d171552a3a451/optree-0.11.0-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading optree-0.11.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.1->tensorflow-macos) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.1->tensorflow-macos) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.1->tensorflow-macos) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.1->tensorflow-macos) (2024.6.2)
# Requirement already satisfied: markdown>=2.6.8 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.1->tensorflow-macos) (3.4.1)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.17,>=2.16->tensorflow==2.16.1->tensorflow-macos)
#   Obtaining dependency information for tensorboard-data-server<0.8.0,>=0.7.0 from https://files.pythonhosted.org/packages/7a/13/e503968fefabd4c6b2650af21e110aa8466fe21432cd7c43a84577a89438/tensorboard_data_server-0.7.2-py3-none-any.whl.metadata
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.1->tensorflow-macos) (2.2.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow==2.16.1->tensorflow-macos) (2.1.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from rich->keras>=3.0.0->tensorflow==2.16.1->tensorflow-macos) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from rich->keras>=3.0.0->tensorflow==2.16.1->tensorflow-macos) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow==2.16.1->tensorflow-macos) (0.1.0)
# Downloading tensorflow_macos-2.16.1-cp311-cp311-macosx_12_0_arm64.whl (2.2 kB)
# Downloading tensorflow-2.16.1-cp311-cp311-macosx_12_0_arm64.whl (227.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.0/227.0 MB 1.8 MB/s eta 0:00:0000:0100:03
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading h5py-3.11.0-cp311-cp311-macosx_11_0_arm64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 2.2 MB/s eta 0:00:0000:0100:01
# Downloading keras-3.3.3-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 2.1 MB/s eta 0:00:0000:0100:01
# Downloading libclang-18.1.1-py2.py3-none-macosx_11_0_arm64.whl (26.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.4/26.4 MB 2.1 MB/s eta 0:00:0000:0100:01
# Downloading ml_dtypes-0.3.2-cp311-cp311-macosx_10_9_universal2.whl (389 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 389.8/389.8 kB 1.8 MB/s eta 0:00:00a 0:00:01
# Downloading tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 2.0 MB/s eta 0:00:0000:0100:01
# Downloading tensorflow_io_gcs_filesystem-0.37.0-cp311-cp311-macosx_12_0_arm64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 1.6 MB/s eta 0:00:0000:0100:01
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Downloading optree-0.11.0-cp311-cp311-macosx_11_0_arm64.whl (274 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.7/274.7 kB 2.1 MB/s eta 0:00:00a 0:00:01
# Using cached rich-13.7.1-py3-none-any.whl (240 kB)
# Installing collected packages: namex, libclang, tensorflow-io-gcs-filesystem, tensorboard-data-server, optree, ml-dtypes, h5py, google-pasta, astunparse, tensorboard, rich, keras, tensorflow, tensorflow-macos
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.4.0
#     Uninstalling ml-dtypes-0.4.0:
#       Successfully uninstalled ml-dtypes-0.4.0
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.9.0
#     Uninstalling h5py-3.9.0:
#       Successfully uninstalled h5py-3.9.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 1.8.0
#     Uninstalling tensorboard-1.8.0:
#       Successfully uninstalled tensorboard-1.8.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 1.8.0
#     Uninstalling tensorflow-1.8.0:
#       Successfully uninstalled tensorflow-1.8.0
# Successfully installed astunparse-1.6.3 google-pasta-0.2.0 h5py-3.11.0 keras-3.3.3 libclang-18.1.1 ml-dtypes-0.3.2 namex-0.0.8 optree-0.11.0 rich-13.7.1 tensorboard-2.16.2 tensorboard-data-server-0.7.2 tensorflow-2.16.1 tensorflow-io-gcs-filesystem-0.37.0 tensorflow-macos-2.16.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow-metal
# Out:
# Collecting tensorflow-metal
#   Obtaining dependency information for tensorflow-metal from https://files.pythonhosted.org/packages/52/56/8373f5751011304a346f07e5423e69f809b626989d2541ae9e816ae7ced2/tensorflow_metal-1.1.0-cp311-cp311-macosx_12_0_arm64.whl.metadata
#   Downloading tensorflow_metal-1.1.0-cp311-cp311-macosx_12_0_arm64.whl.metadata (1.2 kB)
# Requirement already satisfied: wheel~=0.35 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from tensorflow-metal) (0.43.0)
# Requirement already satisfied: six>=1.15.0 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from tensorflow-metal) (1.16.0)
# Downloading tensorflow_metal-1.1.0-cp311-cp311-macosx_12_0_arm64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 2.0 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: tensorflow-metal
# Successfully installed tensorflow-metal-1.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (1.4.1.post1)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from scikit-learn) (1.24.0)
# Requirement already satisfied: scipy>=1.6.0 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from scikit-learn) (3.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.24.0)
# Requirement already satisfied: packaging>=20.0 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/tirtarumy/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %%
import sys

import tensorflow.keras
import pandas as pd
import sklearn as sk
import scipy as sp
import tensorflow as tf
import platform

print(f"Python Platform: {platform.platform()}")
print(f"Tensor Flow Version: {tf.__version__}")
print(f"Keras Version: {tensorflow.keras.__version__}")
print()
print(f"Python {sys.version}")
print(f"Pandas {pd.__version__}")
print(f"Scikit-Learn {sk.__version__}")
print(f"MediaPipe {mp.__version__}")
print(f"SciPy {sp.__version__}")
gpu = len(tf.config.list_physical_devices('GPU'))>0
print("GPU is", "available" if gpu else "NOT AVAILABLE")
# Out:
# Python Platform: macOS-14.5-arm64-arm-64bit
# Tensor Flow Version: 2.16.1
# Keras Version: 3.3.3
#
# Python 3.11.5 (main, Sep 11 2023, 08:31:25) [Clang 14.0.6 ]
# Pandas 2.2.1
# Scikit-Learn 1.4.1.post1
# MediaPipe 0.10.14
# SciPy 1.12.0
# GPU is available

# %% [markdown]
# # Keypoint using MP Holistic

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def  mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_default_landmarks(image,results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image,results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION,
                              mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1),
                              mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                              )
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=1))
                              #mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=1)
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS)
                              # mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=1),
                              # mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=1))
    # Draw right hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS)
                              # mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=1),
                              # mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=1))

# %%
mp_drawing.DrawingSpec??
# Out:
# Init signature:
# mp_drawing.DrawingSpec(
#     color: Tuple[int, int, int] = (224, 224, 224),
#     thickness: int = 2,
#     circle_radius: int = 2,
# ) -> None
# Docstring:      DrawingSpec(color: Tuple[int, int, int] = (224, 224, 224), thickness: int = 2, circle_radius: int = 2)
# Source:
# @dataclasses.dataclass
# class DrawingSpec:
#   # Color for drawing the annotation. Default to the white color.
#   color: Tuple[int, int, int] = WHITE_COLOR
#   # Thickness for drawing the annotation. Default to 2 pixels.
#   thickness: int = 2
#   # Circle radius. Default to 2 pixels.
#   circle_radius: int = 2
# File:           ~/anaconda3/lib/python3.11/site-packages/mediapipe/python/solutions/drawing_utils.py
# Type:           type
# Subclasses:

# %%
cap = cv2.VideoCapture(0)
#accessing mediapipe pose model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
        #read feed
        ret, frame = cap.read()

        #make detections
        image, results = mediapipe_detection(frame, holistic)
        # print(results)

        #draw landmarks
        draw_styled_landmarks(image, results)

        #show to screen
        cv2.imshow('Sign Lang Recognition', image)
        #break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1719408785.789443  544331 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88.1), renderer: Apple M1
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1719408785.916158  551545 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1719408785.926152  551542 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1719408785.928630  551543 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1719408785.928677  551542 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1719408785.929081  551549 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1719408785.932317  551546 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1719408785.936160  551542 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1719408785.937196  551543 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# /Users/tirtarumy/anaconda3/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 9
#       6 ret, frame = cap.read()
#       8 #make detections
# ----> 9 image, results = mediapipe_detection(frame, holistic)
#      10 # print(results)
#      11
#      12 #draw landmarks
#      13 draw_styled_landmarks(image, results)
#
# Cell In[3], line 4, in mediapipe_detection(image, model)
#       2 image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
#       3 image.flags.writeable = False                  # Image is no longer writeable
# ----> 4 results = model.process(image)                 # Make prediction
#       5 image.flags.writeable = True                   # Image is now writeable
#       6 image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
#
# File ~/anaconda3/lib/python3.11/site-packages/mediapipe/python/solutions/holistic.py:160, in Holistic.process(self, image)
#     136 def process(self, image: np.ndarray) -> NamedTuple:
#     137   """Processes an RGB image and returns the pose landmarks, left and right hand landmarks, and face landmarks on the most prominent person detected.
#     138
#     139   Args:
#    (...)
#     157          "enable_segmentation" is set to true.
#     158   """
# --> 160   results = super().process(input_data={'image': image})
#     161   if results.pose_landmarks:  # pytype: disable=attribute-error
#     162     for landmark in results.pose_landmarks.landmark:  # pytype: disable=attribute-error
#
# File ~/anaconda3/lib/python3.11/site-packages/mediapipe/python/solution_base.py:340, in SolutionBase.process(self, input_data)
#     334   else:
#     335     self._graph.add_packet_to_input_stream(
#     336         stream=stream_name,
#     337         packet=self._make_packet(input_stream_type,
#     338                                  data).at(self._simulated_timestamp))
# --> 340 self._graph.wait_until_idle()
#     341 # Create a NamedTuple object where the field names are mapping to the graph
#     342 # output stream names.
#     343 if self._output_stream_type_info is None:
#
# KeyboardInterrupt:

# %%
results
# Out:
# mediapipe.python.solution_base.SolutionOutputs

# %%
draw_styled_landmarks(frame, results)

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # Extract keypoint values

# %%
len(results.left_hand_landmarks.landmark)
# Out:
# 21

# %%
pose = []
for res in results.pose_landmarks.landmark:
    test = np.array([res.x, res.y, res.z, res.visibility])
    pose.append(test)

# %%
pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)

# %%
def extract_keypoint(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    return np.concatenate([pose, lh, rh, face])

# %%
result_test = extract_keypoint(results)

# %%
result_test
# Out:
# array([ 0.51222652,  0.4757916 , -0.56370205, ...,  0.5636903 ,
#         0.39383566,  0.00790111])

# %%
np.save('0', result_test)

# %%
np.load('0.npy')
# Out:
# array([ 0.51222652,  0.4757916 , -0.56370205, ...,  0.5636903 ,
#         0.39383566,  0.00790111])

# %% [markdown]
# # Setup Folder for Collections

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data')

# Actions that we try to detect
actions = np.array([ 'Halo','Perkenalkan', 'Nama', 'Saya'])

# Thirty videos worth of data
no_sequences = 30

# Videos are going to be 30 frames in length
sequence_length = 30

# %%
# Halo => 30 different videos, for 1 video has 30 frames (np.array)
## 0 
## 1
## ...
## 29

# Perkenalkan
# nama
#...

# %%
for action in actions:
    for sequence in range(no_sequences):
        try:
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence))) # create sub directory
        except:
            pass

# %% [markdown]
# # Collect Keypoint Values for Training & Testing

# %%
cap = cv2.VideoCapture(0)
#accessing mediapipe pose model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:

    #loop through actions
    for action in actions:
        #loop through sequences aka videos
        for sequence in range(no_sequences):
            #loop through video length aka frames/sequece_length
            for frame_num in range(sequence_length):

                #read feed
                ret, frame = cap.read()

                #make detections
                image, results = mediapipe_detection(frame, holistic)
                print(results)

                #draw landmarks
                draw_styled_landmarks(image, results)

                #apply wait logic
                if frame_num == 0:
                    cv2.putText(image, 'Memulai pengumpulan Data', (120,200), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # cv2.imshow('Sign Lang Recognition', image)
                    cv2.waitKey(1800)

                else:
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # cv2.imshow('Sign Lang Recognition', image)

                # New export logic for keypoints
                keypoints = extract_keypoint(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                #show to screen
                cv2.imshow('Sign Lang Recognition', image)

                #break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break

    cap.release()
    cv2.destroyAllWindows()
# Out:
# I0000 00:00:1719408871.766795  544331 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88.1), renderer: Apple M1
# W0000 00:00:1719408871.936910  552349 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1719408871.948883  552349 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1719408871.951136  552349 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1719408871.951340  552353 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1719408871.952889  552352 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1719408871.958060  552355 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1719408871.964409  552354 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1719408871.964717  552351 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ...
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Preprocess Data and Create Labels and features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'Halo': 0, 'Perkenalkan': 1, 'Nama': 2, 'Saya': 3}

# %%
sequences, labels = [], []

for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(labels).shape
# Out:
# (120,)

# %%
np.array(sequences).shape
# Out:
# (120, 30, 1662)

# %%
X = np.array(sequences)

# %%
y = to_categorical(labels).astype(int)

# %%
y.shape
# Out:
# (120, 4)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
X_train.shape
# Out:
# (114, 30, 1662)

# %% [markdown]
# # Build and train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import TensorBoard
from keras.callbacks import EarlyStopping, Callback

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
class CustomEarlyStopping(Callback):
    def __init__(self, monitor='categorical_accuracy', value=0.95, verbose=1):
        super(Callback, self).__init__()
        self.monitor = monitor
        self.value = value
        self.verbose = verbose

    def on_epoch_end(self, epoch, logs={}):
        current = logs.get(self.monitor)
        if current is None:
            print(f"Warning: Early stopping requires {self.monitor} available!")
        if current >= self.value:
            if self.verbose > 0:
                print(f"\nEpoch {epoch}: early stopping THR")
            self.model.stop_training = True

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
early_stopping = EarlyStopping(monitor='loss', patience=3, restore_best_weights=True)
custom_early_stopping = CustomEarlyStopping(monitor='categorical_accuracy', value=0.85, verbose=1)

# %%
# model.fit(X_train, y_train, epochs=800, callbacks=[tb_callback])
history = model.fit(X_train, y_train, epochs=850, callbacks=[early_stopping, custom_early_stopping, tb_callback])
# Out:
# Epoch 1/850
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 16s 3s/step - categorical_accuracy: 0.2308 - loss: 2.7082
# Epoch 2/850
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - categorical_accuracy: 0.2393 - loss: 1.7773
# Epoch 3/850
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - categorical_accuracy: 0.2079 - loss: 1.5092
# Epoch 4/850
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - categorical_accuracy: 0.2169 - loss: 1.4033
# Epoch 5/850
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - categorical_accuracy: 0.2211 - loss: 1.3716
# Epoch 6/850
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 12s 3s/step - categorical_accuracy: 0.3495 - loss: 1.3594
# Epoch 7/850
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - categorical_accuracy: 0.3145 - loss: 1.3163
# Epoch 8/850
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - categorical_accuracy: 0.5633 - loss: 1.1900
# Epoch 9/850
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - categorical_accuracy: 0.3242 - loss: 1.7275
# Epoch 10/850
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - categorical_accuracy: 0.4059 - loss: 1.2034
# Epoch 11/850
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - categorical_accuracy: 0.6016 - loss: 1.1438
# Epoch 12/850
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - categorical_accuracy: 0.5687 - loss: 1.0018
# Epoch 13/850
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - categorical_accuracy: 0.6025 - loss: 1.1926
# Epoch 14/850
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - categorical_accuracy: 0.5385 - loss: 1.0418
# Epoch 15/850
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - categorical_accuracy: 0.6649 - loss: 0.7798
# Epoch 16/850
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - categorical_accuracy: 0.7596 - loss: 0.7409
# Epoch 17/850
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - categorical_accuracy: 0.4144 - loss: 1.9633
# Epoch 18/850
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - categorical_accuracy: 0.2441 - loss: 1.3137

# %%
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_15 (LSTM)                  │ (None, 30, 64)         │       442,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_16 (LSTM)                  │ (None, 30, 128)        │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_17 (LSTM)                  │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 4)              │           132 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,790,126 (6.83 MB)
#  Trainable params: 596,708 (2.28 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,193,418 (4.55 MB)

# %% [markdown]
# # Make Predictions

# %%
res = model.predict(X_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 625ms/step

# %%
actions[np.argmax(res[5])]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 actions[np.argmax(res[6])]
#
# IndexError: index 6 is out of bounds for axis 0 with size 6

# %%
actions[np.argmax(y_test[5])]
# Out:
# 'Saya'

# %% [markdown]
# # Save Weights

# %%
model.save('action.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# del model

# %%
model.load_weights('action.h5')

# %% [markdown]
# # Evaluation using Confusion Matrix and Accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[3, 0],
#         [0, 3]],
#
#        [[4, 1],
#         [0, 1]],
#
#        [[4, 0],
#         [1, 1]]])

# %%
accuracy_score(ytrue, yhat)
# Out:
# 0.8333333333333334

# %% [markdown]
# # Test in Real Time

# %%
from scipy import stats

# %%
colors = [(245,117,16), (245,117,16), (245,117,16), (245,117,16), (245,117,16)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
plt.figure(figsize=(18,18))
plt.imshow(prob_viz(res, actions, image, colors))
plt.imshow(frame)
plt.imshow()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[112], line 2
#       1 plt.figure(figsize=(18,18))
# ----> 2 plt.imshow(prob_viz(res, actions, image, colors))
#       3 plt.imshow(frame)
#       4 plt.imshow()
#
# Cell In[111], line 5, in prob_viz(res, actions, input_frame, colors)
#       3 output_frame = input_frame.copy()
#       4 for num, prob in enumerate(res):
# ----> 5     cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
#       6     cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
#       8 return output_frame
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
# 1. New detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.5 #set threshold for predictions, if > 0.1 then show output

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoint(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            
        #3. Viz logic
            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            # image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (720, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       4 predictions = []
#       5 threshold = 0.5 #set threshold for predictions, if > 0.1 then show output
# ----> 7 cap = cv2.VideoCapture(0)
#       8 # Set mediapipe model
#       9 with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
#
# NameError: name 'cv2' is not defined

# %%
cap.release()
cv2.destroyAllWindows()

# %%
res[np.argmax(res)]
# Out:
# 0.18768495

# %%
np.expand_dims(X_test[0], axis=0).shape
# Out:
# (1, 30, 1662)

# %%
res.shape
# Out:
# (10,)

# %%
image.shape
# Out:
# (720, 1280, 3)

# %%
actions.shape
# Out:
# (10,)
